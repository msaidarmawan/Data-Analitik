# %% [markdown]
# <a href="https://colab.research.google.com/github/msaidarmawan/Data-Analitik/blob/main/Data_Analitik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Library dan Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/Dataset/food_delivery_datasets.csv')

# %%
df #menlihat data keseluruhan
# Out:
#         order_id  voucher_amount  ...     status  random_id
# 0     FOOD-10455               0  ...  Completed   0.511149
# 1     FOOD-10985               0  ...  Completed   0.832936
# 2     FOOD-10911               0  ...  Completed   0.828026
# 3     FOOD-10932               0  ...  Completed   0.239377
# 4     FOOD-10961               0  ...  Completed   0.995587
# ...          ...             ...  ...        ...        ...
# 1071  FOOD-10921               0  ...  Completed   0.248328
# 1072  FOOD-10265            5000  ...  Completed   0.268251
# 1073  FOOD-10534               0  ...  Completed   0.132528
# 1074  FOOD-10158               0  ...  Completed   0.167946
# 1075  FOOD-10770               0  ...  Completed   0.358051
#
# [1076 rows x 11 columns]

# %% [markdown]
# # Processing Data

# %%
df['cust_id']=df['cust_id'].map(str)

# %%
df=df[df.status=='Completed']
df.reset_index(drop=True)
# Out:
#        order_id  voucher_amount  ...     status  random_id
# 0    FOOD-10455               0  ...  Completed   0.511149
# 1    FOOD-10985               0  ...  Completed   0.832936
# 2    FOOD-10911               0  ...  Completed   0.828026
# 3    FOOD-10932               0  ...  Completed   0.239377
# 4    FOOD-10961               0  ...  Completed   0.995587
# ..          ...             ...  ...        ...        ...
# 876  FOOD-10921               0  ...  Completed   0.248328
# 877  FOOD-10265            5000  ...  Completed   0.268251
# 878  FOOD-10534               0  ...  Completed   0.132528
# 879  FOOD-10158               0  ...  Completed   0.167946
# 880  FOOD-10770               0  ...  Completed   0.358051
#
# [881 rows x 11 columns]

# %%
df['completed_order']=1

# %%
df=pd.concat([df['cust_id'],df['status'],df['completed_order']], axis=1)
df.columns=['cust_id','status','completed_order']
df.head()
# Out:
#    cust_id     status  completed_order
# 0  1089034  Completed                1
# 1   180146  Completed                1
# 2   366528  Completed                1
# 3   511038  Completed                1
# 4  1220358  Completed                1

# %%
df=df.groupby(['cust_id'])
df1=df[['completed_order']].sum()
df1.reset_index()
# Out:
#      cust_id  completed_order
# 0    1008214                3
# 1    1008998                3
# 2    1010922                4
# 3    1011942                3
# 4    1012995                4
# ..       ...              ...
# 131   929284                8
# 132   940042                3
# 133   943758                4
# 134   949010                4
# 135   960065                6
#
# [136 rows x 2 columns]

# %%
df_final=df1.sort_values(by='completed_order',ascending=False)
df_final.reset_index()
# Out:
#      cust_id  completed_order
# 0    1094787               26
# 1     316834               25
# 2     366721               25
# 3     366528               24
# 4     697545               20
# ..       ...              ...
# 131  1510407                1
# 132   185166                1
# 133   472361                1
# 134   514284                1
# 135    22895                1
#
# [136 rows x 2 columns]

# %% [markdown]
# # Visualisasi

# %%
plt.figure(figsize=(25,10))
plt.plot(df1)

plt.title('Total Order yang Diselesaikan Per Customer')
plt.xlabel('Customer ID')
plt.xticks(rotation=90)
plt.ylabel('Completed Order')

plt.show()
